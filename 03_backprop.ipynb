# %% [markdown]
# https://www.youtube.com/watch?v=3Kb0QS6z7WA&list=PLqnslRFeH2UrcDBWF5mfPGpqQDSta6VK4&index=4
#
# https://github.com/patrickloeber/pytorchTutorial/blob/master/04_backpropagation.py

# %%
import torch

x = torch.tensor(1.0)
y = torch.tensor(2.0)

# This is the parameter we want to optimize -> requires_grad = True

w = torch.tensor(1.0,requires_grad = True)

# forward pass to compute loss

y_pred = w * x

loss = (y_pred - y)**2
print("loss",loss)

#backward pass to compute gradient dloss/dw

loss.backward()
print(w.grad)

# update weights
#next forward and backward pass..

#continue optimizing
# update weights, this operation should not be part of the computational graph

with torch.no_grad():

  w -= -0.01 * w.grad

# dont' forget to zero the gradients
w.grad.zero_()

# next forward and backward pass
# Out:
# loss tensor(1., grad_fn=<PowBackward0>)
# tensor(-2.)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-9c89ef83fd04> in <cell line: 33>()
#      31
#      32 # dont' forget to zero the gradients
# ---> 33 w.grad.zero_()
#      34
#      35 # next forward and backward pass
#
# AttributeError: 'NoneType' object has no attribute 'zero_'
